# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0,2.0])
y_train = np.array([300.0,500.0])
print(f"x_train = {x_train}")
print(f"y_train = {y_train}")
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
m = x_train.shape[0]
print(f"m = {m}")
# Out:
# m = 2

# %%
for i in range(m):
    print(f"x_{i} = {x_train[i]}")
    print(f"y_{i} = {y_train[i]}")
# Out:
# x_0 = 1.0
# y_0 = 300.0
# x_1 = 2.0
# y_1 = 500.0

# %%
plt.plot(x_train, y_train, 'x', c='r')
plt.title('House Price ')
plt.xlabel('Size in Square Feet')
plt.ylabel('Price in 1000 $')
plt.show()

# %%
#  Set w and b to 100
w = 100
b = 100
print(f"w = {w}")
print(f"b = {b}")
# Out:
# w = 100
# b = 100

# %%
def forward_propagation(x_train, w, b):
    m = x_train.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x_train[i] + b
    return f_wb

# %%
tmp_wb = forward_propagation(x_train, w, b)
plt.plot(x_train, tmp_wb, label='Our Prediction', c='b')
plt.scatter(x_train, y_train, label='Actual Prediction', c='r', marker='x')
plt.title('House Price ')
plt.xlabel('Size in Square Feet')
plt.ylabel('Price in 1000 $')
plt.legend()
plt.show()

# %%
#  Set w= 200 and b = 100
w = 200
b = 100
tmp_wb = forward_propagation(x_train, w, b)
plt.plot(x_train, tmp_wb, label='Our Prediction', c='b')
plt.scatter(x_train, y_train, label='Actual Prediction', c='r', marker='x')
plt.title('House Price ')
plt.xlabel('Size in Square Feet')
plt.ylabel('Price in 1000 $')
plt.legend()
plt.show()

# %%
x_i = 1.2 
cost_1200sqft = w * x_i + b 
print(f"Cost of 1200 sqft house is {cost_1200sqft} $")
# Out:
# Cost of 1200 sqft house is 340.0 $

# %% [markdown]
# ## Problem Statement
#
# You would like a model which can predict housing prices given the size of the house.
# Let's use the same two data points as before the previous lab- a house with 1000 square feet sold for \\$300,000 and a house with 2000 square feet sold for \\$500,000.
#
#
# | Size (1000 sqft)     | Price (1000s of dollars) |
# | -------------------| ------------------------ |
# | 1                 | 300                      |
# | 2                  | 500                      |

# %%
# !pip install ipympl
# %matplotlib widget
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
x_train = np.array([1.0,2.0])
y_train = np.array([300.0,500.0])
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
def compute_cost(x,y,w,b):
    m = x.shape[0]
    total_cost = 0
    for i in range(m):
        f_wb = w * x[i] + b
        total_cost += (f_wb - y[i])**2
    total_cost = (1/(2*m)) * total_cost
    return total_cost

# %%
plt_intuition(x_train,y_train)
# Out:
# interactive(children=(IntSlider(value=150, description='w', max=400, step=10), Output()), _dom_classes=('widge…

# %%
plt.close('all') 
fig, ax, dyn_items = plt_stationary(x_train, y_train)
updater = plt_update_onclick(fig, ax, x_train, y_train, dyn_items)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Convex Cost surface

# The fact that the cost function squares the loss ensures that the 'error surface' is convex like a soup bowl. 
# It will always have a minimum that can be reached by following the gradient in all dimensions
soup_bowl()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
